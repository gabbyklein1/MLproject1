# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('merge_data_update.csv', index_col=0)

# %%
data
# Out:
#             PID  GrLivArea  SalePrice  MSSubClass MSZoning  LotFrontage  \
# 0     909176150        856     126000          30       RL          NaN
# 1     905476230       1049     139500         120       RL         42.0
# 2     911128020       1001     124900          30  C (all)         60.0
# 3     535377150       1039     114000          70       RL         80.0
# 4     534177230       1665     227000          60       RL         70.0
# ...         ...        ...        ...         ...      ...          ...
# 2575  903205040        952     121000          30       RL          NaN
# 2576  905402060       1733     139600          20       RL          NaN
# 2577  909275030       2002     145000          90       RH         82.0
# 2578  907192040       1842     217500          60       RL          NaN
# 2579  906223180       1911     215000          60       RL         80.0
#
#       LotArea Street Alley LotShape  ...    ClassPr_S  \
# ...

# %%
ppsft = pd.concat([data['SalePrice']/data['GrLivArea']], axis=1)

# %%
data['ppsft'] = pd.concat([ppsft], axis=1)

# %%
data
# Out:
#             PID  GrLivArea  SalePrice  MSSubClass MSZoning  LotFrontage  \
# 0     909176150        856     126000          30       RL          NaN
# 1     905476230       1049     139500         120       RL         42.0
# 2     911128020       1001     124900          30  C (all)         60.0
# 3     535377150       1039     114000          70       RL         80.0
# 4     534177230       1665     227000          60       RL         70.0
# ...         ...        ...        ...         ...      ...          ...
# 2575  903205040        952     121000          30       RL          NaN
# 2576  905402060       1733     139600          20       RL          NaN
# 2577  909275030       2002     145000          90       RH         82.0
# 2578  907192040       1842     217500          60       RL          NaN
# 2579  906223180       1911     215000          60       RL         80.0
#
#       LotArea Street Alley LotShape  ...                        ClassSc_S  \
# ...

# %%
data.groupby('BldgType').agg(['mean', 'count'])
# Out:
#                    PID          GrLivArea            SalePrice        \
#                   mean count         mean count           mean count
# BldgType
# 1Fam      7.213195e+08  2139  1502.985975  2139  181854.923796  2139
# 2fmCon    8.362802e+08    54  1487.166667    54  125428.240741    54
# Duplex    7.325089e+08    87  1692.643678    87  141175.494253    87
# Twnhs     6.443515e+08    98  1255.408163    98  137329.489796    98
# TwnhsE    6.402235e+08   202  1329.202970   202  187586.450495   202
#
#           MSSubClass       LotFrontage        ...        OthAc_S        \
#                 mean count        mean count  ...           mean count
# BldgType                                      ...
# 1Fam       41.778869  2139   73.207114  1743  ...  169244.554455  2121
# 2fmCon    184.444444    54   67.411765    51  ...  128137.962963    54
# Duplex     90.000000    87   72.785714    70  ...  124558.620690    87
# ...

# %%
data
# Out:
#             PID  GrLivArea  SalePrice  MSSubClass MSZoning  LotFrontage  \
# 0     909176150        856     126000          30       RL          NaN
# 1     905476230       1049     139500         120       RL         42.0
# 2     911128020       1001     124900          30  C (all)         60.0
# 3     535377150       1039     114000          70       RL         80.0
# 4     534177230       1665     227000          60       RL         70.0
# ...         ...        ...        ...         ...      ...          ...
# 2575  903205040        952     121000          30       RL          NaN
# 2576  905402060       1733     139600          20       RL          NaN
# 2577  909275030       2002     145000          90       RH         82.0
# 2578  907192040       1842     217500          60       RL          NaN
# 2579  906223180       1911     215000          60       RL         80.0
#
#       LotArea Street Alley LotShape  ...                        ClassSc_S  \
# ...
